# %% [markdown]
# # Vul hieronder je gegevens in:
# - **Naam:** ...
# - **Klas:** ...

# %%
# Programmeeropdracht: Treinreisplanner
#
# Schrijf een programma dat de prijs van een treinreis berekent.
# De gebruiker voert de afstand in kilometers in, kiest of hij in de spits
# of daluren reist, en voert zijn leeftijd in.
#
# Het programma moet voldoen aan de volgende eisen:
# - Gebruik functies
# - Gebruik iteratie (bijv. while-loop)
# - Gebruik selectie (if/elif/else)
# - Gebruik variabelen (string, float, boolean of integer)
# - Geen lijsten gebruiken
#
# Functionaliteit:
# 1. Vraag de gebruiker om de afstand in kilometers.
# 2. Vraag of de reis in de spits of daluren is.
# 3. Vraag de leeftijd van de reiziger.
# 4. Bereken de basisprijs: €0.12 per kilometer.
# 5. Pas toeslag toe voor spits (+20%) of korting voor dal (-10%).
# 6. Pas leeftijdskorting toe:
#    - Kinderen (<12): 50% korting
#    - Senioren (65+): 30% korting
# 7. Toon de uiteindelijke prijs.
# 8. Vraag of de gebruiker nog een reis wil berekenen.
#
# Gebruik minimaal één functie, bijvoorbeeld:
# - bereken_basisprijs(km)
# - pas_tijdskorting_toe(prijs, spits_of_dal)
# - pas_leeftijdskorting_toe(prijs, leeftijd)

# %%
# Schrijf hieronder je oplossing voor de Treinreisplanner
