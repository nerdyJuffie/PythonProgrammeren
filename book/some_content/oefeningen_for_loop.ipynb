# %% [markdown]
# # Python Oefeningen: For Loops
#
# ---
# **Instructie:** Maak eerst de opdrachten in de code-secties en klik daarna [hier](uitwerkingen_for_loops.ipynb) om naar de uitwerkingen te gaan.

# %%
# Voer je gegevens hieronder in en druk op Enter
naam = input("Wat is je naam? ")
klas = input("In welke klas zit je? ")

print(f"\nSucces met de opdrachten, {naam} uit klas {klas}!")

# %% [markdown]
# ### Oefening 1: De tafel van...
# Maak een programma waarin je vraagt aan de gebruiker van welk getal deze de tafel wil zien. Print vervolgens de tafel in de vorm 1 x getal = uitkomst.

# %%
# Typ hier je code voor de tafel van...

# %% [markdown]
# ### Oefening 2: Aftellen maar...
# Schrijf de code waarin je aftelt van 10 naar 0. Als je bij 0 aankomt, dan print je 'Happy New Year!'. Het aftellen moet je ook laten zien.

# %%
# Typ hier je code voor het aftellen...

# %% [markdown]
# ### Oefening 3: Tel alle even getallen op...
# Maak een programma waarin je de gebruiker vraagt tot welk getal alle even getallen opgeteld moeten worden. Tel vervolgens alle even getallen op en print de som hiervan.

# %%
# Typ hier je code voor de even getallen...
