# %% [markdown]
# # Vul hieronder je gegevens in:
# - **Naam:** ...
# - **Klas:** ...

# %%
# Programmeeropdracht: Raad-het-Getal Spel
#
# Schrijf een programma waarin de computer een geheim getal kiest tussen 1 en 100.
# De speler moet dit getal raden.
#
# Het programma moet voldoen aan de volgende eisen:
# - Gebruik functies
# - Gebruik iteratie (while-loop)
# - Gebruik selectie (if/elif/else)
# - Gebruik variabelen (string, float, boolean of integer)
# - Geen lijsten gebruiken
#
# Functionaliteit:
# 1. Laat de computer een geheim getal kiezen (bijv. met random.randint).
# 2. Vraag de speler om een gok te doen.
# 3. Geef hints:
#    - "Hoger" als het getal te laag is.
#    - "Lager" als het getal te hoog is.
# 4. Tel het aantal pogingen.
# 5. Als de speler het goed heeft, toon dan het aantal pogingen.
# 6. Vraag of de speler opnieuw wil spelen.
#
# Gebruik minimaal één functie, bijvoorbeeld:
# - kies_geheim_getal()
# - speel_ronde()

# %%
# Schrijf hieronder je oplossing voor het Raad-het-Getal spel
