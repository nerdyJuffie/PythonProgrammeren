# %% [markdown]
# # Testpagina voor JupyterLite
# Als het goed is, zie je rechtsboven een **raket-icoontje**.
# 1. Klik op de raket.
# 2. Kies **JupyterLite**.
# 3. Wacht tot de cel hieronder veranderd in een interactieve box.

# %%
import numpy as np
import matplotlib.pyplot as plt

print("Hallo! Als je dit ziet, werkt Python in je browser!")

# Een klein grafiekje om de bibliotheken te testen
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title("Sinus golf")
plt.show()
