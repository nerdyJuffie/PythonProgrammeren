# %% [markdown]
# # Verkorte Operatoren
#
# ## 1. Theorie: Verkorte schrijfwijze
# In plaats van `aantal = aantal + 1` kun je in Python `aantal += 1` gebruiken. Dit werkt voor diverse operatoren:
#
# | Operator | Betekenis | Voorbeeld | Lang uitgeschreven |
# | :--- | :--- | :--- | :--- |
# | `+=` | Optellen | `x += 3` | `x = x + 3` |
# | `-=` | Aftrekken | `x -= 2` | `x = x - 2` |
# | `*=` | Vermenigvuldigen | `x *= 5` | `x = x * 5` |
# | `/=` | Delen | `x /= 2` | `x = x / 2` |
# | `//=` | Floor Division | `x //= 3` | `x = x // 3` |
# | `%=` | Modulo (Rest) | `x %= 4` | `x = x % 4` |
#
# ---
#
# ## 2. Opdracht: De Pinautomaat
# Neem de onderstaande code over in de code-cel en vervang de commentaarregels door de juiste code.
# Test je code met de volgende inputs: **74, 321, 1035**.

# %%
# OPDRACHT: Maak de pinautomaat code af
print("Welkom bij de pinautomaat")
opname = int(input("Hoeveel euro wilt u opnemen? "))

# vijftig = # bereken hier hoeveel briefjes iemand krijgt
# opname = # bereken hier hoeveel rest er over blijft

# Ga hieronder verder voor de rest van de briefjes en munten...


print("U krijgt:")
# Print hier de resultaten zoals in het voorbeeld

# %% [markdown]
# ---
# ## 💡 Zelfcontrole
#
# <details>
# <summary><b>Klik hier om jouw code te vergelijken met de uitwerking</b></summary>
#
# ### De Uitwerking
# Hieronder zie je hoe je de verkorte operatoren `//=` en `%=` efficiënt kunt gebruiken:
#
# ```python
# print("Welkom bij de pinautomaat")
# opname = int(input("Hoeveel euro wilt u opnemen? "))
#
# vijftig = opname // 50
# opname %= 50
#
# twintig = opname // 20
# opname %= 20
#
# tien = opname // 10
# opname %= 10
#
# vijf = opname // 5
# opname %= 5
#
# twee = opname // 2
# opname %= 2
#
# een = opname // 1
# opname %= 1
#
# print("U krijgt:")
# print(vijftig, "briefjes van 50", twintig, "briefjes van 20", tien, "briefjes van 10")
# print(vijf, "briefjes van 5", twee, "munten van 2", een, "munten van 1")
# ```
#
# </details>
