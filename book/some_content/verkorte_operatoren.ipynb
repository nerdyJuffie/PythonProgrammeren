# %% [markdown]
# # Verkorte Operatoren
#
# ## 1. Theorie: Verkorte schrijfwijze
# In plaats van `aantal = aantal + 1` kun je in Python `aantal += 1` gebruiken.
#
# | Operator | Betekenis | Voorbeeld | Lang uitgeschreven |
# | :--- | :--- | :--- | :--- |
# | `+=` | Optellen | `x += 3` | `x = x + 3` |
# | `-=` | Aftrekken | `x -= 2` | `x = x - 2` |
# | `*=` | Vermenigvuldigen | `x *= 5` | `x = x * 5` |
# | `/=` | Delen | `x /= 2` | `x = x / 2` |
# | `//=` | Floor Division | `x //= 3` | `x = x // 3` |
# | `%=` | Modulo (Rest) | `x %= 4` | `x = x % 4` |

# %% [markdown]
# ### Instructieafbeelding
# ![Uitleg Verkorte Operatoren](../figures/verkort1.jpg)

# %% [markdown]
# ---
# ## 2. Opdracht: De Pinautomaat
# Test je code met de volgende inputs: **74, 321, 1035**.

# %% [markdown]
# Kijk goed naar het voorbeeld, zodat je weet wat je moet coderen!
#
# ![Opdracht Pinautomaat](../figures/verkort2.jpg)

# %%
# Maak de pinautomaat code af
print("Welkom bij de pinautomaat")
opname = int(input("Hoeveel euro wilt u opnemen? "))

# Jouw code hier...

# %% [markdown]
# ---
# ## 💡 Zelfcontrole
#
# <details>
# <summary><b>Klik hier om jouw code te vergelijken met de uitwerking</b></summary>
#
# ### De Uitwerking
#
# ```python
# vijftig = opname // 50
# opname %= 50
#
# twintig = opname // 20
# opname %= 20
#
# tien = opname // 10
# opname %= 10
#
# vijf = opname // 5
# opname %= 5
#
# twee = opname // 2
# opname %= 2
#
# een = opname // 1
# opname %= 1
#
# print("U krijgt:")
# print(vijftig, "x 50,", twintig, "x 20,", tien, "x 10,", vijf, "x 5,", twee, "x 2,", een, "x 1")
# ```
#
# </details>
