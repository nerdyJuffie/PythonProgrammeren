# %% [markdown]
# # Les: Verkorte Operatoren
#
# ## 1. Theorie: Verkorte schrijfwijze
# In plaats van `aantal = aantal + 1` kun je in Python `aantal += 1` gebruiken. Dit werkt voor diverse operatoren:
#
# | Operator | Betekenis | Voorbeeld | Lang uitgeschreven |
# | :--- | :--- | :--- | :--- |
# | `+=` | Optellen | `x += 3` | `x = x + 3` |
# | `-=` | Aftrekken | `x -= 2` | `x = x - 2` |
# | `*=` | Vermenigvuldigen | `x *= 5` | `x = x * 5` |
# | `/=` | Delen | `x /= 2` | `x = x / 2` |
# | `//=` | Floor Division | `x //= 3` | `x = x // 3` |
# | `%=` | Modulo (Rest) | `x %= 4` | `x = x % 4` |
#
# ---
#
# ## 2. Opdracht: De Pinautomaat
# Vul de code in de cel hieronder aan. Gebruik de variabelen `vijftig`, `twintig`, `tien`, `vijf`, `twee` en `een` om het aantal briefjes/munten te berekenen. Gebruik de verkorte operatoren (`//=` of `%=`) om het bedrag steeds bij te werken.
#
# <details>
# <summary><b>👉 Klik hier voor de uitwerking (alleen kijken als je er niet uitkomt!)</b></summary>
#
# ### De Oplossing
# ```python
# print("Welkom bij de pinautomaat")
# opname = int(input("Hoeveel euro wilt u opnemen?"))
#
# vijftig = opname // 50
# opname %= 50
#
# twintig = opname // 20
# opname %= 20
#
# tien = opname // 10
# opname %= 10
#
# vijf = opname // 5
# opname %= 5
#
# twee = opname // 2
# opname %= 2
#
# een = opname // 1
# opname %= 1
#
# print("U krijgt:")
# print(vijftig, "x 50,", twintig, "x 20,", tien, "x 10,", vijf, "x 5,", twee, "x 2,", een, "x 1")
# ```
# </details>

# %%
# OPDRACHT: Maak de pinautomaat code af
print("Welkom bij de pinautomaat")
opname = int(input("Hoeveel euro wilt u opnemen? "))

# Bereken hieronder de briefjes en munten (gebruik //= en %=)
vijftig = 
opname = 

# ... ga hier verder ...

print("U krijgt:")
# Print hier het resultaat
