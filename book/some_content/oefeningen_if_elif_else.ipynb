# %% [markdown]
# # Oefenopdracht: Geavanceerde If-Elif-Else
#
# In deze opdrachten ga je aan de slag met complexere vergelijkingen. Lees de instructies per opdracht goed door.
#
# > *Let op: Als je de browser ververst zonder te downloaden of op te slaan, gaat je werk verloren!*
# ---

# %%
# Voer hier je gegevens in
naam = input("Wat is je volledige naam? ")
klas = input("In welke klas zit je? ")

print(f"\nGegevens opgeslagen. Succes met de opdracht, {naam}!")

# %% [markdown]
# ## Opdracht 1: Kleinste van 3 getallen bepalen
# Schrijf een programma waarin:
# * Je de gebruiker vraagt naar een eerste, tweede en derde geheel getal.
# * Je deze waarden toekent aan variabelen (bijv. `getal1`, `getal2`, `getal3`).
# * Je bepaalt welk getal het kleinste van de 3 getallen is.
# * Je de gevonden waarde afdrukt op het scherm.

# %%
# Typ hier je code voor Opdracht 1:

# %% [markdown]
# ## Opdracht 2: Aantal gelijke getallen bepalen
# Schrijf een programma waarin:
# * Je de gebruiker vraagt naar drie gehele getallen.
# * Je bepaalt hoeveel gelijke getallen er zijn tussen deze drie.
# * De mogelijke uitkomsten zijn **0** (geen enkele gelijk), **2** (twee zijn hetzelfde) of **3** (alle drie zijn hetzelfde).
# * Je de gevonden waarde afdrukt.

# %%
# Typ hier je code voor Opdracht 2:

# %% [markdown]
# ## Opdracht 3: Kleinste van 5 getallen bepalen (Stappenplan)
# Dit is een belangrijke opdracht om te leren hoe je efficiënt vergelijkt. Volg exact de stappen:
#
# 1. Vraag de gebruiker naar een **eerste** geheel getal. Omdat dit de eerste waarde is, is dit op dit moment de kleinste. Sla dit op in de variabele `kleinste_getal`.
# 2. Vraag de gebruiker naar een **tweede** geheel getal.
#    * **Als** deze waarde kleiner is dan `kleinste_getal`, dan ken je deze nieuwe waarde toe aan de variabele `kleinste_getal`.
#    * **Anders** verander je niets.
# 3. Herhaal deze stappen (vragen en vergelijken) ook voor het **derde, vierde en vijfde** getal.
# 4. Druk aan het einde de waarde van `kleinste_getal` af. Dit is nu immers de kleinste van alle 5 de waarden.

# %%
# Typ hier je code voor Opdracht 3:

# %% [markdown]
# <details>
# <summary style="background-color: #e1f5fe; padding: 10px; border-radius: 8px; border: 2px solid #01579b; cursor: pointer; font-weight: bold; color: #01579b;">
#     🔵 Klik hier om de antwoorden van de opdrachten te bekijken
# </summary>
#
# ```python
# # opdracht 1: kleinste van 3 getallen bepalen
# getal1 = int(input('geef een geheel getal: '))
# getal2 = int(input('geef nog een geheel getal: '))
# getal3 = int(input('geef nogmaals een geheel getal: '))
# if getal1 < getal2 and getal1 < getal3:
#     print(f'{getal1} is het kleinste getal')
# elif getal2 < getal3 and getal2 < getal1:
#     print(f'{getal2} is het kleinste getal')
# elif getal3 < getal1 and getal3 < getal2:
#     print(f'{getal3} is het kleinste getal')
# else:
#     print('Er zijn gelijke getallen die samen de kleinste zijn!')
#
# # opdracht 2: Aantal gelijke getallen bepalen
# getal1 = int(input('geef een geheel getal: '))
# getal2 = int(input('geef nog een geheel getal: '))
# getal3 = int(input('geef nogmaals een geheel getal: '))
#
# if getal1 == getal2 and getal1 == getal3:
#     aantal_gelijk = 3
# elif getal1 == getal2 or getal1 == getal3 or getal2 == getal3:
#     aantal_gelijk = 2
# else:
#     aantal_gelijk = 0
# print("aantal gelijk:", aantal_gelijk)
#
# # opdracht 3: Kleinste van 5 getallen bepalen
# kleinste_getal = int(input('voer het 1e getal in: '))
#
# getal = int(input('voer het 2e getal in: '))
# if getal < kleinste_getal:
#     kleinste_getal = getal
#
# getal = int(input('voer het 3e getal in: '))
# if getal < kleinste_getal:
#     kleinste_getal = getal
#
# getal = int(input('voer het 4e getal in: '))
# if getal < kleinste_getal:
#     kleinste_getal = getal
#
# getal = int(input('voer het 5e getal in: '))
# if getal < kleinste_getal:
#     kleinste_getal = getal
#
# print("Het kleinste getal is:", kleinste_getal)
# ```
#
# </details>
