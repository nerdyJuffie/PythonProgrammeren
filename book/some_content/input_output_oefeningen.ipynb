# %% [markdown]
# # Praktijkopdrachten: Input, Output en Foutopsporing
# In dit werkblad ga je twee grotere programma's schrijven. Je leert hoe je gegevens netjes onder elkaar print en hoe je fouten in je code herkent en oplost.
#
# ### ⚠️ Instructies
# 1. Klik op de **raket (Launch Thebe)** om de codeblokken te activeren.
# 2. Voer de opdrachten uit in de grijze cellen.
# 3. **Belangrijk:** Houd je schrift bij de hand voor de vragen bij opdracht 2.

# %% [markdown]
# ## Opdracht 1: Aanmeldpaal Ziekenhuis (opdracht3_2.py)
# Maak een programma voor een aanmeldpaal in een ziekenhuis. De paal moet de volgende stappen doorlopen:
# 1. Begroet de persoon in het algemeen.
# 2. Vraag om de **naam** en **geboortedatum**.
# 3. Vraag om de **afdeling**.
# 4. Vraag om de **naam van de arts**.
# 5. Print daarna een 'bonnetje' uit dat er netjes uitziet met alle ingevulde gegevens.

# %%
# Schrijf hier je code voor de aanmeldpaal

# %% [markdown]
# <details>
# <summary><b>Klik hier voor de oplossing van Opdracht 1</b></summary>
#
# ![Oplossing Opdracht 1](../figures/input1.png)
#
# </details>

# %% [markdown]
# ## Opdracht 2: Adreslabel en Debuggen (opdracht3_3.py)
# ### Deel A: Het Adreslabel
# 1. Vraag de gebruiker om de volgende gegevens: **Voornaam, Achternaam, Straatnaam, Huisnummer, Postcode en Woonplaats**.
# 2. Print een adreslabel waarbij de gegevens netjes onder elkaar staan.
# 3. **Pas je code aan:** Verander de variabele `huisnummer` in een `int` (bijv. `huisnummer = int(input(...))` ).
# 4. Run het programma opnieuw.
#
# > **! Noteer in je schrift:** Welke fout krijg je nu te zien? Los de fout daarna op in je printregel (tip: denk aan `str()` of gebruik een f-string).

# %%
# Schrijf hier je code voor het adreslabel (Deel A)

# %% [markdown]
# <details>
# <summary><b>Klik hier voor de oplossing van Deel A</b></summary>
#
# ![Oplossing Deel A](../figures/input2.png)
#
# ![oplossing Deel A2](../figures/input2A.png)
# </details>

# %% [markdown]
# ### Deel B: Strings combineren
# Voeg de volgende regel toe aan je code: `print("Beste voornaam, ")`.
#
# > **! Noteer in je schrift:** Welke fout geeft het programma aan? Verbeter de fout daarna zodat de echte naam van de gebruiker wordt geprint.

# %%
# Voeg hier de code van Deel B toe en test deze

# %% [markdown]
# <details>
# <summary><b>Klik hier voor de oplossing van Deel B</b></summary>
#
# ![Oplossing Deel B](../figures/input3.png)
#
# </details>

# %% [markdown]
# ### Deel C: De Afsluiting
# Schrijf een kort berichtje van 3 regels en sluit af met de volgende code: `print(met vriendelijke groet, de informaticajuf)`
#
# > **! Noteer in je schrift:** Wat valt je op aan deze fout? Runt het programma eerst een stukje voordat het de fout tegenkomt, of stopt het direct? Verbeter daarna de code.

# %%
# Voeg hier de afsluiting toe (Deel C)

# %% [markdown]
# <details>
# <summary><b>Klik hier voor de oplossing van Deel C</b></summary>
#
# ![Oplossing Deel C](../figures/input2C.png)
#
# </details>

# %% [markdown]
# ## 🏁 Klaar?
# Controleer of alle opdrachten naar behoren werken.
