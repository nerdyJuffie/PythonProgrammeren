# %% [markdown]
# # Inleveropdracht: Booleaanse Logica
#
# **Naam:** ...
# **Klas:** ...
# **Datum:** 23 maart 2026
#
# ---
# Sla dit bestand op als booleaans_oefenen_jouwnaam.ipynb en lever in op Teams
# !! Controleer je eigen antwoord [hier](booleaanse_logica_uitwerking.ipynb) !!---
#
# ## Introductie
# In deze opdracht ga je laten zien dat je kunt werken met vergelijkingen (`==`, `!=`, `<`, `>`, `<=`, `>=`) en logische operatoren (`and`, `or`, `not`).
#
# ### Puntenverdeling:
# - Opdracht 1: 20 punten
# - Opdracht 2: 30 punten
# - Opdracht 3: 30 punten
# - Opdracht 4 (Bonus): 20 punten

# %% [markdown]
# ## Opdracht 1: De Uitsmijter
# Een club hanteert de volgende regels:
# 1. Je moet minimaal 18 jaar oud zijn.
# 2. Je moet een geldig ID-bewijs bij je hebben.
#
# Maak een programma dat vraagt om de leeftijd en of iemand een ID heeft. Gebruik de `and` operator om te bepalen of de bezoeker naar binnen mag.

# %%
# UITWERKING OPDRACHT 1
leeftijd = int(input("Hoe oud ben je? "))
heeft_id = input("Heb je een ID bij je? (ja/nee) ")

# Schrijf hier de booleaanse expressie:
mag_naar_binnen = 

print("Toegang verleend:", mag_naar_binnen)

# %% [markdown]
# ## Opdracht 2: De Kortingskaart
# In een pretpark krijg je korting als:
# - Je jonger bent dan 12 jaar.
# - OF als je ouder bent dan 65 jaar.
#
# Schrijf een programma dat de leeftijd vraagt en met `or` berekent of de bezoeker korting krijgt.

# %%
# UITWERKING OPDRACHT 2

# %% [markdown]
# ## Opdracht 3: De Login-Check
# Maak een systeem waarbij twee voorwaarden waar moeten zijn:
# 1. De gebruikersnaam moet `"student_python"` zijn.
# 2. Het wachtwoord moet `"geheim"` zijn.
#
# Gebruik `input()` voor beide velden en print of de login geslaagd is (`True` of `False`).

# %%
# UITWERKING OPDRACHT 3

# %% [markdown]
# ## Opdracht 4 (Bonus): De Complexere Check
# Je mag alleen een specifieke game spelen als:
# - Je 12 jaar of ouder bent **EN** toestemming hebt van je ouders.
# - **OF** als je 16 jaar of ouder bent (dan is toestemming niet meer nodig).
#
# Gebruik haakjes `()` om je logica te groeperen.

# %%
# UITWERKING OPDRACHT 4
leeftijd = int(input("Wat is je leeftijd? "))
toestemming = input("Hebben je ouders toestemming gegeven? (ja/nee) ") == "ja"

# Jouw code hieronder:
