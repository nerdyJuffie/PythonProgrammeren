# %% [markdown]
# # Inleverformulier Informatica
#
# ---
# **Instructie:** Voer eerst de onderstaande cel uit om je gegevens te registreren. Maak daarna de opdrachten in de code-secties.
#
# ## Hoe lever ik dit in?
# 1. Werk de onderstaande opdrachten uit in de lege codeblokken.
# 2. Sla het bestand op (**Bestand** -> **Opslaan** of `Ctrl+S`).
# 3. Download het `.ipynb` bestand naar je computer.
# 4. Ga naar de opdracht in **Microsoft Teams** en voeg het bestand toe als bijlage.
#
# ---

# %%
# Voer hier je gegevens in
naam = input("Wat is je volledige naam? ")
klas = input("In welke klas zit je? ")

print(f"\nGegevens geregistreerd voor: {naam} (Klas: {klas})")
print("Je kunt nu beginnen met de opdrachten.")

# %% [markdown]
# # Opdracht 1: Tafel van een gevraagd getal
#
# Maak een programmaatje waarbij je de gebruiker vraagt van welk getal ze de tafel willen zien. Vervolgens toon je de volledige tafel van 1 x getal tot en met 10 x getal.

# %%
# Schrijf hier je code voor opdracht 1

# %% [markdown]
# ---
#
# # Opdracht 2: Raad het getal
#
# Laat de computer een random getal genereren van 1 tot 100. De speler moet het getal raden. Zolang het getal niet geraden is, moet je de vraag stellen een getal te noemen. Geef ook aan of het getal hoger of lager is dan het ingevoerde getal.
#
# **Extra opdracht:** Houd bij hoeveel keer er geraden is.

# %%
# Schrijf hier je code voor opdracht 2
