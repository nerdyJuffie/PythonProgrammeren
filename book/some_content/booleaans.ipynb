# %% [markdown]
# # Booleaanse Expressies en Logica
#
# Een booleaanse expressie is een ‘test’ die de uitkomst **True** (waar) of **False** (onwaar) heeft.
#
# ### 1. Vergelijkingsoperatoren
# Je maakt basisexpressies met deze operatoren:
#
# | Operator | Betekenis |
# | :--- | :--- |
# | `==` | is gelijk aan |
# | `!=` | is ongelijk aan |
# | `<` | is kleiner dan |
# | `>` | is groter dan |
# | `<=` | is kleiner dan of gelijk aan |
# | `>=` | is groter dan of gelijk aan |

# %%
naam = "Sanne"
leeftijd = 23

stemmen = leeftijd > 18
kinderkorting = leeftijd <= 12

print(naam, leeftijd, "mag al stemmen:", stemmen)
print("Is de naam Sanne?", naam == "Sanne")

# %% [markdown]
# ### 2. Combineren met `and` en `or`
#
# Als je meerdere booleaanse expressies tegelijkertijd wilt controleren, gebruik je `and` en/of `or`.
#
# #### De `and` operator
# Bij `and` is de uitkomst alleen **True** als **beide** kanten waar zijn. Is één kant (of beide) onwaar? Dan is de hele uitkomst **False**.

# %%
leeftijd = int(input("Wat is uw leeftijd? "))
rijbewijs = input("Heeft u uw rijbewijs? (ja/nee) ")

autorijden = leeftijd >= 17 and rijbewijs == "ja"

print("Mag al autorijden?", autorijden)

# %% [markdown]
# #### De `or` operator
# Met `or` is de uitkomst **True** zodra **minstens één** van de kanten waar is.

# %%
leeftijd = int(input("Wat is uw leeftijd? "))

korting = leeftijd <= 10 or leeftijd > 65

print("Heb je recht op korting?", korting)

# %% [markdown]
# ### 3. De `not` operator
# De `not` operator draait de uitkomst van een booleaanse expressie simpelweg om. Het maakt van `True` een `False`, en van `False` een `True`.

# %%
regen = True
print("Regent het?", regen)
print("Is het droog?", not regen)

# %% [markdown]
# ---
# ## Eindopdrachten
#
# 1. **Bioscoop:** Je mag naar de film als je 16 jaar of ouder bent OF als je toestemming hebt van je ouders (`toestemming = "ja"`). Schrijf de code.
# 2. **Inloggen:** Maak een systeem dat controleert of de gebruikersnaam `"admin"` is EN het wachtwoord `"1234"`.
# 3. **Zwemles:** Je mag het diepe water in als je een A-diploma hebt EN een B-diploma. Gebruik de variabelen `heeft_a` en `heeft_b`.
# 4. **Niet jarig:** Gebruik `not` om te controleren of de variabele `vandaag_jarig` (zet deze op `False`) inderdaad betekent dat er géén taart gegeten wordt.

# %%
# Voer hier je uitwerkingen uit:

# %% [markdown]
# ### Uitwerkingen van de opdrachten
#
# ```python
# # bioscoop
# leeftijd = int(input("leeftijd "))
# toestemming = input("toestemming? ja/nee")
# film = leeftijd >= 16 or toestemming == "ja"
# print(film)
#
# # inloggen
# gebruikersnaam = input("gebruikersnaam: ")
# wachtwoord = input("wachtwoord: ")
# toegang = gebruikersnaam == "admin" and wachtwoord == "1234"
# print(toegang)
#
# # zwemles
# heeft_a = input("heb je zwemdiploma A? ja/nee") == "ja"
# heeft_b = input("heb je ook zwemdiploma B? ja/nee") == "ja"
# diepe_water = heeft_a and heeft_b
# print(diepe_water)
#
# # niet jarig
# jarig = input("ben je vandaag jarig? ja/nee ") == "ja"
# niet_jarig = not(jarig)
# print(f"Ben je vandaag jarig? {niet_jarig}, als False dan wordt er geen taart gegeten!")
# ```

# %% [markdown]
# ---
# ## Ga naar de [oefenopdrachten](booleaans_oefenen.ipynb)
