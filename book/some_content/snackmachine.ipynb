# %% [markdown]
# # Snackautomaat 2.0
#
# ## Vul hieronder je gegevens in:
# - **Naam:** ...
# - **Klas:** ...

# %%
# Programmeeropdracht: Snackautomaat 2.0
#
# Schrijf een programma dat een snackautomaat simuleert waarin de gebruiker
# meerdere snacks kan toevoegen aan één bestelling. Pas wanneer de gebruiker
# klaar is, wordt het totaal berekend en moet er betaald worden.
#
# Eisen:
# - Gebruik functies
# - Gebruik iteratie (while-loop)
# - Gebruik selectie (if/elif/else)
# - Gebruik variabelen (string, float, boolean of integer)
# - Geen lijsten gebruiken
#
# Functionaliteit:
# 1. Toon een menu met drie snacks (naam + prijs).
# 2. Laat de gebruiker kiezen welke snack hij wil toevoegen.
# 3. Tel de prijs op bij een totaalbedrag.
# 4. Vraag of de gebruiker nog iets wil toevoegen.
# 5. Als de gebruiker klaar is, toon het totaalbedrag.
# 6. Vraag om betaling en controleer of het genoeg is.
# 7. Toon eventueel wisselgeld.

# %%
# Schrijf hieronder je oplossing voor de Snackautomaat 2.0
